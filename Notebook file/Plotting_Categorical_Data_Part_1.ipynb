# %% [markdown]
# # Plotting with categorical data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data=pd.read_csv('/content/heart_failure_clinical_records_dataset 2.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
set(data.dtypes.tolist())
# Out:
# {dtype('int64'), dtype('float64')}

# %%
data.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdde8f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bddc9278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdd7f4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdd33748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdce49b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdd1ac18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdccfe80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdc8f0f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdc8f160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdbf35f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdba8860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdbdaac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdb90d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdb44f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdb03240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94bdab54a8>]],
#       dtype=object)

# %%
data.corr()['DEATH_EVENT'][:-1]
# Out:
# age                         0.253729
# anaemia                     0.066270
# creatinine_phosphokinase    0.062728
# diabetes                   -0.001943
# ejection_fraction          -0.268603
# high_blood_pressure         0.079351
# platelets                  -0.049139
# serum_creatinine            0.294278
# serum_sodium               -0.195204
# sex                        -0.004316
# smoking                    -0.012623
# time                       -0.526964
# Name: DEATH_EVENT, dtype: float64

# %% [markdown]
# # 1. Categorical scatterplots

# %%
sns.catplot(x='DEATH_EVENT',y='age',data=data)

# %%
sns.catplot(x='DEATH_EVENT',y='age',data=data,jitter=False)

# %%
sns.catplot(x='DEATH_EVENT',y='age',data=data,kind='swarm')

# %%
sns.catplot(x='DEATH_EVENT',y='age',hue='sex',data=data,kind='swarm')

# %%
data.head(10)
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  75.0        0                       582  ...        0     4            1
# 1  55.0        0                      7861  ...        0     6            1
# 2  65.0        0                       146  ...        1     7            1
# 3  50.0        1                       111  ...        0     7            1
# 4  65.0        1                       160  ...        0     8            1
# 5  90.0        1                        47  ...        1     8            1
# 6  75.0        1                       246  ...        0    10            1
# 7  60.0        1                       315  ...        1    10            1
# 8  65.0        0                       157  ...        0    10            1
# 9  80.0        1                       123  ...        1    10            1
#
# [10 rows x 13 columns]

# %%
sns.catplot(x='smoking',y='age',hue='sex',data=data,kind='swarm')

# %%
sns.catplot(x='DEATH_EVENT',y='platelets',hue='sex',data=data,kind='swarm')

# %%
sns.catplot(x='high_blood_pressure',y='platelets',hue='sex',data=data,kind='swarm')

# %%
sns.catplot(x='high_blood_pressure',y='platelets',hue='diabetes',data=data,kind='swarm')

# %%
sns.catplot(x='high_blood_pressure',y='platelets',hue='smoking',data=data,kind='swarm')

# %%
x=sns.catplot(x='anaemia',y='platelets',hue='smoking',data=data,kind='swarm')
y=sns.catplot(x='anaemia',y='platelets',hue='sex',data=data,kind='swarm')
z=sns.catplot(x='anaemia',y='platelets',hue='diabetes',data=data,kind='swarm')

# %% [markdown]
# # 2. Boxplots

# %%
data.head(5)
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  75.0        0                       582  ...        0     4            1
# 1  55.0        0                      7861  ...        0     6            1
# 2  65.0        0                       146  ...        1     7            1
# 3  50.0        1                       111  ...        0     7            1
# 4  65.0        1                       160  ...        0     8            1
#
# [5 rows x 13 columns]

# %%
cat=['anaemia','diabetes','smoking','sex']
con=['creatinine_phosphokinase','age','ejection_fraction','platelets','serum_creatinine','serum_sodium']
for x in cat:
  for y in con:
      sns.catplot(x='DEATH_EVENT',y=y,hue=x,kind='box',data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)

# %%
cat=['anaemia','diabetes','smoking','sex']
con=['creatinine_phosphokinase','age','ejection_fraction','platelets','serum_creatinine','serum_sodium']
for x in cat:
  for y in con:
      sns.catplot(x='DEATH_EVENT',y=y,hue=x,kind='boxen',data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)

# %% [markdown]
# # 3.Violinplots

# %%
cat=['anaemia','diabetes','smoking','sex']
con=['creatinine_phosphokinase','age','ejection_fraction','platelets','serum_creatinine','serum_sodium']
for x in cat:
  for y in con:
      sns.catplot(x='DEATH_EVENT',y=y,hue=x,kind='violin',data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)

# %% [markdown]
# # combine swarmplot() or striplot()

# %%
cat=['anaemia','diabetes','smoking','sex']
con=['creatinine_phosphokinase','age','ejection_fraction','platelets','serum_creatinine','serum_sodium']
for y in con:
      plot=sns.catplot(x='DEATH_EVENT',y=y,kind='violin',data=data)
      sns.swarmplot(x='DEATH_EVENT',y=y,data=data,color="k", size=3,ax=plot.ax)

# %% [markdown]
# # 4. Statistical estimation within categories

# %%
cat=['anaemia','diabetes','smoking','sex']
con=['creatinine_phosphokinase','age','ejection_fraction','platelets','serum_creatinine','serum_sodium']
for x in cat:
  for y in con:
      sns.catplot(x='DEATH_EVENT',y=y,hue=x,kind='bar',data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)

# %%
cat=['anaemia','diabetes','smoking','sex','DEATH_EVENT']
for x in cat:
      sns.catplot(x=x,kind='count',data=data)

# %% [markdown]
# # 5. Point plots

# %%
cat=['anaemia','diabetes','smoking','sex']
con=['creatinine_phosphokinase','age','ejection_fraction','platelets','serum_creatinine','serum_sodium']
for x in cat:
  for y in con:
      sns.catplot(x='DEATH_EVENT',y=y,hue=x,kind='point',data=data,markers=["^", "o"], linestyles=["-", "--"],)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:318: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
